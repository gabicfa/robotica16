# %% [markdown]
# # Entregável 1 - visão computacional

# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np
import time as t
print "OpenCV Version : %s " % cv2.__version__
# Out:
# OpenCV Version : 2.4.8

# %% [markdown]
# # Equalização de histograma

# %%
rintin = cv2.imread("RinTinTin.jpg")

# %%
rintin.shape
# Out:
# (240, 320, 3)

# %%
rintin_gray = cv2.cvtColor(rintin, cv2.COLOR_RGB2GRAY)

# %%
rintin_gray.shape
# Out:
# (240, 320)

# %%
rintin_gray
# Out:
# array([[21, 39, 42, ..., 41, 41, 37],
#        [22, 40, 44, ..., 42, 42, 37],
#        [23, 41, 45, ..., 42, 43, 38],
#        ...,
#        [14, 28, 35, ..., 18, 18, 17],
#        [16, 29, 36, ..., 18, 17, 17],
#        [18, 31, 38, ..., 18, 17, 17]], dtype=uint8)

# %%
imagem_diagonal = rintin_gray*5
imagem_diagonal
# Out:
# array([[105, 195, 210, ..., 205, 205, 185],
#        [110, 200, 220, ..., 210, 210, 185],
#        [115, 205, 225, ..., 210, 215, 190],
#        ...,
#        [ 70, 140, 175, ...,  90,  90,  85],
#        [ 80, 145, 180, ...,  90,  85,  85],
#        [ 90, 155, 190, ...,  90,  85,  85]], dtype=uint8)

# %%
plt.imshow(rintin_gray, cmap="Greys_r")

# %%
hist,bins = np.histogram((rintin_gray).flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(rintin_gray.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# ## Atividade 1
#
# Realize as seguintes atividades:
#
# 1. O histograma fornecido aproveita bem as faixas de cores?
# 2. Equalize o histograma de maneira que a cumulativa seja uma função linear na diagonal do gráfico
# 3. Plote a imagem desenhada

# %% [markdown]
# 1. Nao aproveita bem as faixas de cores pois ela vai apenas até a intensidade 50.

# %%
#2.
hist,bins = np.histogram(imagem_diagonal.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(imagem_diagonal.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
plt.imshow(imagem_diagonal, cmap="Greys_r")

# %% [markdown]
# ## Atividade 2

# %% [markdown]
# Leia com a OpenCV a figura abaixo:
#
# ![](hall_box_battery1.jpg)
#
# Separe os canais  R e B das imagens e analise seus histogramas.
#
# 1. A partir dos canais R e B e da análise do histograma é possível identificar a caixa vermelha e a bateria azul?
#
# 1. Crie uma imagem numpy em que somente os pixels da caixa vermelha estão brancos e faça seu plot aqui

# %%
imagem = cv2.imread("hall_box_battery1.jpg")
imagem_rgb = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)
plt.imshow(imagem_rgb, interpolation="none")

# %%
imagem_red = imagem_rgb[:,:,0]
plt.imshow(imagem_red)

# %%
plt.imshow(imagem_red, cmap='Greys_r')

# %%
imagem_green = imagem_rgb[:,:,1]
plt.imshow(imagem_green)

# %%
plt.imshow(imagem_green, cmap='Greys_r')

# %%
imagem_blue = imagem_rgb[:,:,2]
plt.imshow(imagem_blue)

# %%
plt.imshow(imagem_green, cmap='Greys_r')

# %%
imagem_vermelho = imagem_red - imagem_green 
imagem_azul = imagem_blue- imagem_green

# %%
plt.imshow(imagem_vermelho, cmap = "Greys_r")

# %%
plt.imshow(imagem_azul, cmap = "Greys_r")

# %%
hist,bins = np.histogram(imagem_vermelho.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(imagem_vermelho.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# A caixa aparenta estar entre 125 e 180

# %%
hist,bins = np.histogram(imagem_azul.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(imagem_azul.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# A bateria pode estar entre 40 e 70

# %%
def vermelho(p):
    if p > 125 and p < 180:
        return 255
    else:
        return 0

vetor_vermelho = np.vectorize(vermelho)
caixa = [vetor_vermelho(p) for p in imagem_vermelho]
plt.imshow(caixa, cmap = "Greys_r")

# %%
def azul(p):
    if p > 40 and p < 70:
        return 255
    else:
        return 0

vetor_azul = np.vectorize(azul)
bateria = [vetor_azul(p) for p in imagem_azul]
plt.imshow(bateria, cmap = "Greys_r")

# %%
def vermelho2(p1, p2):
    if p1 == 255 and p2 == 0:
        return 255
    else:
        return 0

vetor_vermelho2 = np.vectorize(vermelho2)
caixa3 = [vetor_vermelho2(caixa2[p], bateria2[p]) for p in range(len(caixa2))]
plt.imshow(caixa3, cmap = "Greys_r")

# %%
red = np.uint8([[[255,0,0 ]]])
hsv_red = cv2.cvtColor(red,cv2.COLOR_BGR2HSV)
print hsv_red
# Out:
# [[[120 255 255]]]

# %%
img_hsv=cv2.cvtColor(imagem, cv2.COLOR_BGR2HSV)

lower_red = np.array([0, 100, 100])
upper_red = np.array([10, 255, 255])
mask0 = cv2.inRange(img_hsv, lower_red, upper_red)

lower_red = np.array([125, 100, 100])
upper_red = np.array([179, 255, 255])
mask1 = cv2.inRange(img_hsv, lower_red, upper_red)

mask1 = mask0+mask1

output_img = imagem.copy()
output_img[np.where(mask==0)] = 0

output_hsv = img_hsv.copy()
output_hsv[np.where(mask==0)] = 0

# %%
plt.imshow(output_hsv)

# %% [markdown]
# Tentei usar mascara, porém nao conseguir deixar a caixa branca
